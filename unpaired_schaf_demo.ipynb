# %%
# versioning issues, run this cell once as a temporary fix

! pip install numpy==1.24.4
! pip install torch==2.0.1 torchvision==0.15.2 torchtext==0.15.2
! pip install scgpt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting numpy==1.24.4
#   Downloading numpy-1.24.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 181.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyro-ppl 1.9.1 requires torch>=2.0, but you have torch 1.8.1 which is incompatible.
# pytorch-lightning 1.9.5 requires torch>=1.10.0, but you have torch 1.8.1 which is incompatible.
# scgpt 0.2.4 requires torch>=1.13.0, but you have torch 1.8.1 which is incompatible.
# torchmetrics 1.7.3 requires torch>=2.0.0, but you have torch 1.8.1 which is incompatible.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# Successfully installed numpy-1.24.4
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.15.2
#   Downloading torchvision-0.15.2-cp39-cp39-manylinux1_x86_64.whl.metadata (11 kB)
# Collecting torchtext==0.15.2
#   Downloading torchtext-0.15.2-cp39-cp39-manylinux1_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: filelock in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch==2.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch==2.0.1) (4.14.0)
# Requirement already satisfied: sympy in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch==2.0.1) (1.14.0)
# Requirement already satisfied: networkx in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch==2.0.1) (3.2.1)
# Requirement already satisfied: jinja2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch==2.0.1) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torchvision==0.15.2) (1.24.4)
# Requirement already satisfied: requests in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torchvision==0.15.2) (2.32.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torchvision==0.15.2) (11.2.1)
# Requirement already satisfied: tqdm in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torchtext==0.15.2) (4.67.1)
# Collecting torchdata==0.6.1 (from torchtext==0.15.2)
#   Downloading torchdata-0.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: setuptools in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (80.9.0)
# Requirement already satisfied: wheel in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: urllib3>=1.25 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torchdata==0.6.1->torchtext==0.15.2) (2.5.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1)
#   Downloading cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from requests->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from requests->torchvision==0.15.2) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from sympy->torch==2.0.1) (1.3.0)
# Downloading torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 265.6 MB/s eta 0:00:00a 0:00:01
# Downloading torchvision-0.15.2-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 243.4 MB/s eta 0:00:00
# Downloading torchtext-0.15.2-cp39-cp39-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 479.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 258.3 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 244.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 265.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 309.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 225.8 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 264.1 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 245.5 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 272.8 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 266.3 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 256.2 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Downloading torchdata-0.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 9.9 MB/s eta 0:00:00eta 0:00:01
# Downloading triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 259.9 MB/s eta 0:00:00a 0:00:01
# Downloading cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 273.3 MB/s eta 0:00:00
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, cmake, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchdata, torchvision, torchtext
#   Attempting uninstall: triton━━━━╸━━━━━━━━━━━━━ 12/18 [nvidia-cudnn-cu11]11]1]
#     Found existing installation: triton 3.0.0━━━━━━━━━━━━━ 12/18 [nvidia-cudnn-cu11]
#     Uninstalling triton-3.0.0:━━━━━━╸━━━━━━━━━━━ 13/18 [triton]n-cu11]
#       Successfully uninstalled triton-3.0.01m╸━━━━━━━━━━━ 13/18 [triton]
#   Attempting uninstall: torch━━━━━━━╸━━━━━━━━━━━ 13/18 [triton]
#     Found existing installation: torch 1.8.10m━━━━━━━━━━━ 13/18 [triton]
#     Uninstalling torch-1.8.1:━━━━━━━━━━╺━━━━━━━━ 14/18 [torch]
#       Successfully uninstalled torch-1.8.1m╺━━━━━━━━ 14/18 [torch]
#   Attempting uninstall: torchvision━━━━━━╺━━━━━━ 15/18 [torchdata]
#     Found existing installation: torchvision 0.9.1m━━━━━━ 15/18 [torchdata]
#     Uninstalling torchvision-0.9.1:━━╺━━━━━━ 15/18 [torchdata]
#       Successfully uninstalled torchvision-0.9.1━━━━━━ 15/18 [torchdata]
#   Attempting uninstall: torchtext━━━━━━━━━━╸━━━━ 16/18 [torchvision]
#     Found existing installation: torchtext 0.12.0━━━━ 16/18 [torchvision]
#     Uninstalling torchtext-0.12.0:━━━━━╸━━━━ 16/18 [torchvision]
#       Successfully uninstalled torchtext-0.12.0m╸━━━━ 16/18 [torchvision]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [torchtext]0m [torchvision]
# Successfully installed cmake-4.0.3 lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torchdata-0.6.1 torchtext-0.15.2 torchvision-0.15.2 triton-2.0.0
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: scgpt in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: cell-gears<0.0.3 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.0.2)
# Requirement already satisfied: datasets<3.0.0,>=2.3.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (2.21.0)
# Requirement already satisfied: leidenalg>=0.8.10 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.10.2)
# Requirement already satisfied: numba>=0.55.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.60.0)
# Requirement already satisfied: orbax<0.1.8 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.1.7)
# Requirement already satisfied: pandas>=1.3.5 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (2.3.0)
# Requirement already satisfied: scanpy<2.0.0,>=1.9.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (1.10.3)
# Requirement already satisfied: scib<2.0.0,>=1.0.3 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (1.1.7)
# Requirement already satisfied: scikit-misc>=0.1.4 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.3.1)
# Requirement already satisfied: scvi-tools<1.0,>=0.16.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.20.3)
# Requirement already satisfied: torch>=1.13.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (2.0.1)
# Requirement already satisfied: torchtext in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.15.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (4.14.0)
# Requirement already satisfied: umap-learn>=0.5.3 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scgpt) (0.5.7)
# Requirement already satisfied: numpy in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from cell-gears<0.0.3->scgpt) (1.24.4)
# Requirement already satisfied: tqdm in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from cell-gears<0.0.3->scgpt) (4.67.1)
# Requirement already satisfied: scikit-learn in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from cell-gears<0.0.3->scgpt) (1.6.1)
# Requirement already satisfied: networkx in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from cell-gears<0.0.3->scgpt) (3.2.1)
# Requirement already satisfied: dcor in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from cell-gears<0.0.3->scgpt) (0.6)
# Requirement already satisfied: filelock in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (2.32.4)
# Requirement already satisfied: xxhash in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (3.5.0)
# Requirement already satisfied: multiprocess in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.3.0->scgpt) (2024.6.1)
# Requirement already satisfied: aiohttp in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (3.12.13)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (0.33.1)
# Requirement already satisfied: packaging in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from datasets<3.0.0,>=2.3.0->scgpt) (6.0.2)
# Requirement already satisfied: absl-py in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (2.3.0)
# Requirement already satisfied: cached_property in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (1.5.2)
# Requirement already satisfied: importlib_resources in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (6.5.2)
# Requirement already satisfied: msgpack in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (1.1.1)
# Requirement already satisfied: etils in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (1.5.2)
# Requirement already satisfied: jax>=0.4.6 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (0.4.30)
# Requirement already satisfied: jaxlib in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (0.4.30)
# Requirement already satisfied: tensorstore>=0.1.20 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (0.1.69)
# Requirement already satisfied: nest_asyncio in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax<0.1.8->scgpt) (1.6.0)
# Requirement already satisfied: anndata>=0.8 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.10.9)
# Requirement already satisfied: get-annotations in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.1.2)
# Requirement already satisfied: h5py>=3.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (3.14.0)
# Requirement already satisfied: joblib in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.5.1)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.4)
# Requirement already satisfied: matplotlib>=3.6 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (3.9.4)
# Requirement already satisfied: natsort in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (8.4.0)
# Requirement already satisfied: patsy in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.5.13)
# Requirement already satisfied: scipy>=1.8 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.13.1)
# Requirement already satisfied: seaborn>=0.13 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.13.2)
# Requirement already satisfied: session-info in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.0.0)
# Requirement already satisfied: statsmodels>=0.13 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.14.4)
# Requirement already satisfied: pydot in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scib<2.0.0,>=1.0.3->scgpt) (4.0.1)
# Requirement already satisfied: igraph>=0.10 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scib<2.0.0,>=1.0.3->scgpt) (0.11.9)
# Requirement already satisfied: llvmlite in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scib<2.0.0,>=1.0.3->scgpt) (0.43.0)
# Requirement already satisfied: deprecated in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scib<2.0.0,>=1.0.3->scgpt) (1.2.18)
# Requirement already satisfied: chex in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.1.89)
# Requirement already satisfied: docrep>=0.3.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.3.2)
# Requirement already satisfied: flax in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.8.5)
# Requirement already satisfied: ml-collections>=0.1.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.1.1)
# Requirement already satisfied: mudata>=0.1.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.2.4)
# Requirement already satisfied: numpyro in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.18.0)
# Requirement already satisfied: openpyxl>=3.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (3.1.5)
# Requirement already satisfied: optax in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.2.4)
# Requirement already satisfied: pyro-ppl>=1.6.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.9.1)
# Requirement already satisfied: pytorch-lightning<1.10.0,>=1.9.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.9.5)
# Requirement already satisfied: rich>=12.0.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (14.0.0)
# Requirement already satisfied: torchmetrics>=0.11.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.7.3)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools<1.0,>=0.16.0->scgpt) (0.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (6.6.0)
# Requirement already satisfied: propcache>=0.2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (3.10)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (1.11.2)
# Requirement already satisfied: exceptiongroup in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (1.3.0)
# Requirement already satisfied: six in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from docrep>=0.3.2->scvi-tools<1.0,>=0.16.0->scgpt) (1.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from huggingface-hub>=0.21.2->datasets<3.0.0,>=2.3.0->scgpt) (1.1.5)
# Requirement already satisfied: texttable>=1.6.2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from igraph>=0.10->scib<2.0.0,>=1.0.3->scgpt) (1.7.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from jax>=0.4.6->orbax<0.1.8->scgpt) (0.5.1)
# Requirement already satisfied: opt-einsum in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from jax>=0.4.6->orbax<0.1.8->scgpt) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from jax>=0.4.6->orbax<0.1.8->scgpt) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.4.6->orbax<0.1.8->scgpt) (3.23.0)
# Requirement already satisfied: setuptools in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from lightning-utilities>=0.6.0.post0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools<1.0,>=0.16.0->scgpt) (80.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (1.4.7)
# Requirement already satisfied: pillow>=8 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy<2.0.0,>=1.9.1->scgpt) (2.9.0.post0)
# Requirement already satisfied: contextlib2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from ml-collections>=0.1.1->scvi-tools<1.0,>=0.16.0->scgpt) (21.6.0)
# Requirement already satisfied: et-xmlfile in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from openpyxl>=3.0->scvi-tools<1.0,>=0.16.0->scgpt) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from pandas>=1.3.5->scgpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from pandas>=1.3.5->scgpt) (2025.2)
# Requirement already satisfied: pyro-api>=0.1.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from pyro-ppl>=1.6.0->scvi-tools<1.0,>=0.16.0->scgpt) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from rich>=12.0.0->scvi-tools<1.0,>=0.16.0->scgpt) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from rich>=12.0.0->scvi-tools<1.0,>=0.16.0->scgpt) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->scvi-tools<1.0,>=0.16.0->scgpt) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from scikit-learn->cell-gears<0.0.3->scgpt) (3.6.0)
# Requirement already satisfied: sympy in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (1.14.0)
# Requirement already satisfied: jinja2 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torch>=1.13.0->scgpt) (2.0.0)
# Requirement already satisfied: wheel in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->scgpt) (0.45.1)
# Requirement already satisfied: cmake in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.13.0->scgpt) (4.0.3)
# Requirement already satisfied: lit in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.13.0->scgpt) (18.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from chex->scvi-tools<1.0,>=0.16.0->scgpt) (1.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from deprecated->scib<2.0.0,>=1.0.3->scgpt) (1.17.2)
# Requirement already satisfied: orbax-checkpoint in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from flax->scvi-tools<1.0,>=0.16.0->scgpt) (0.6.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from jinja2->torch>=1.13.0->scgpt) (3.0.2)
# Requirement already satisfied: multipledispatch in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from numpyro->scvi-tools<1.0,>=0.16.0->scgpt) (1.0.0)
# Requirement already satisfied: protobuf in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (6.31.1)
# Requirement already satisfied: humanize in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (4.12.3)
# Requirement already satisfied: stdlib-list in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from session-info->scanpy<2.0.0,>=1.9.1->scgpt) (0.11.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from sympy->torch>=1.13.0->scgpt) (1.3.0)
# Requirement already satisfied: torchdata==0.6.1 in /storage/ccomiter/miniconda3/envs/final_schaf2/lib/python3.9/site-packages (from torchtext->scgpt) (0.6.1)

# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import torch

# Standard library imports
import os
import sys
import json
import math
import random
import argparse
from collections import defaultdict
from pathlib import Path
import datetime
from typing import Dict, List, Tuple, Set, Union, Optional

# Third-party imports
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, ConcatDataset, TensorDataset
import torchvision
from torchvision import transforms
import wandb
import scanpy as sc
from tqdm import tqdm
import sklearn.model_selection
from PIL import Image
import seaborn as sns
from numba import njit, prange
from scipy.stats import wasserstein_distance
from scipy.spatial import cKDTree
import tangram as tg
import imageio.v3 as iio
import cv2
import scgpt
import timm
from einops import rearrange
from torch import einsum
import torch.nn.utils as U

from schaf_method import *

os.environ["CUDA_VISIBLE_DEVICES"] = '7'  # replace as needed 

# Configure system settings
Image.MAX_IMAGE_PIXELS = 933120000  # Allow loading large images
DEVICE = torch.device("cuda:7")  # replace as needed 
device = DEVICE
NUM_WORKERS = 6 if torch.cuda.is_available() else 2
PIN_MEMORY = torch.cuda.is_available()
os.environ["OPENCV_IO_MAX_IMAGE_PIXELS"] = pow(2,40).__str__()

# %%
# Create example single-cell data
reference = sc.datasets.pbmc3k()
real_gene_names = reference.var_names.tolist()

HOLD_OUT_FOLD = 1
fold_to_he = {}
fold_to_he_xs = {}
fold_to_he_ys = {}
fold_to_sc = {}
for fold in range(4):
    n_cells = 1000
    n_genes = 2000
    expression_matrix = np.random.negative_binomial(5, 0.3, size=(n_cells, n_genes))
    adata_sc = sc.AnnData(X=expression_matrix)
    adata_sc.obs.index = [f"cell_{i}" for i in range(n_cells)]
    adata_sc.var.index = real_gene_names[:n_genes]
    adata_sc.obs['cluster'] = np.random.choice([0, 1, 2, 3], n_cells)
    adata_sc.var['gene_col'] = list(adata_sc.var.index)
    sc.pp.log1p(adata_sc)
    fold_to_sc[fold] = adata_sc

    n_cells = 1000
    he_image = np.random.randint(0, 255, size=(1000, 1000, 3), dtype=np.uint8) / 255.
    fold_to_he[fold] = he_image
    fold_to_he_xs[fold] = np.random.choice(list(range(1000)), n_cells)
    fold_to_he_ys[fold] = np.random.choice(list(range(1000)), n_cells) 
    # all hes have 1000 random coords

embedding_maker = ViT_UNI().to(device)
embedding_maker = embedding_maker.eval()
fold_to_he_embed = {}
fold_to_sc_embed = {}
for fold in range(4):
    model_dir = f"/storage/ccomiter/htapp_supervise/new_schaf_experiment_scripts/final_new_schaf_start_jan2324/scgpt_model/scGPT_human/"
    embed_data = scgpt.tasks.embed_data(fold_to_sc[fold], model_dir, gene_col='gene_col', batch_size=64)
    new_adata = sc.AnnData(X=embed_data.obsm['X_scGPT'], obs=embed_data.obs)
    fold_to_sc_embed[fold] = new_adata
    
    the_ds = HistSampleDataset(
        fold_to_he[fold], 
        fold_to_he_xs[fold], 
        fold_to_he_ys[fold], 
        10,
    )
    the_dl = DataLoader(the_ds, batch_size=64, shuffle=0, num_workers=6, pin_memory=1)
    
    with torch.no_grad():
        embeds = []
        for batch in tqdm(the_dl):
            res = embedding_maker(batch.to(device).float()).cpu().detach().numpy()
            embeds.extend(res)    
        torch.cuda.empty_cache()
    embeds = np.array(embeds)
    embed_adata = sc.AnnData(X=embeds,)
    embed_adata.obs['x'] = fold_to_he_xs[fold]
    embed_adata.obs['y'] = fold_to_he_ys[fold]
    fold_to_he_embed[fold] = embed_adata


# fold_to_he_embed
# fold_to_sc_embed

for k, v in fold_to_he_embed.items():
    v.obs['fold'] = k
    fold_to_he_embed[k] = v
for k, v in fold_to_sc_embed.items():
    v.obs['fold'] = k
    fold_to_he_embed[k] = v

HOLD_OUT_FOLD = 1

import anndata as ad

train_he_embeds = ad.concat([fold_to_he_embed[k] for k in range(4) if k != HOLD_OUT_FOLD])
train_sc_embeds = ad.concat([fold_to_sc_embed[k] for k in range(4) if k != HOLD_OUT_FOLD])

test_he_embeds = fold_to_he_embed[HOLD_OUT_FOLD]
test_sc_embeds = fold_to_sc_embed[HOLD_OUT_FOLD]

# fold_to_he_embed
# fold_to_sc_embed

for k, v in fold_to_he_embed.items():
    v.obs['fold'] = k
    fold_to_he_embed[k] = v
for k, v in fold_to_sc_embed.items():
    v.obs['fold'] = k
    fold_to_he_embed[k] = v

HOLD_OUT_FOLD = 1

import anndata as ad

train_he_embeds = ad.concat([fold_to_he_embed[k] for k in range(4) if k != HOLD_OUT_FOLD])
train_sc_embeds = ad.concat([fold_to_sc_embed[k] for k in range(4) if k != HOLD_OUT_FOLD])

test_he_embeds = fold_to_he_embed[HOLD_OUT_FOLD]
test_sc_embeds = fold_to_sc_embed[HOLD_OUT_FOLD]

train_he_dl = DataLoader(UnpairedDataset(train_he_embeds.X, is_hist=1), batch_size=64, shuffle=1, num_workers=6, pin_memory=1)
train_sc_dl = DataLoader(UnpairedDataset(train_sc_embeds.X, is_hist=0), batch_size=64, shuffle=1, num_workers=6, pin_memory=1) 
test_he_dl = DataLoader(UnpairedDataset(test_he_embeds.X, is_hist=1), batch_size=64, shuffle=1, num_workers=6, pin_memory=1)
test_sc_dl = DataLoader(UnpairedDataset(test_sc_embeds.X, is_hist=0), batch_size=64, shuffle=1, num_workers=6, pin_memory=1)

generator = HEGen()
discriminator = Discriminator()
hist_decoder = HEDecoder()
sc_decoder = StandardDecoder(2000)

lr = 1e-4
# Initialize optimizers
gen_optimizer = optim.Adam(generator.parameters(), lr=lr)
disc_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
hist_dec_optimizer = optim.Adam(hist_decoder.parameters(), lr=lr)
sc_dec_optimizer = optim.Adam(sc_decoder.parameters(), lr=lr)

train_decoder_dl = DataLoader(
    ConcatDataset([TensorDataset(
        torch.from_numpy(fold_to_sc_embed[k].X),
        torch.from_numpy(fold_to_sc[k].X),
    ) for k, v in fold_to_sc_embed.items() if k != HOLD_OUT_FOLD]),
    batch_size=128, shuffle=1, num_workers=6, pin_memory=1,
)


criter = nn.MSELoss()
num_epochs = 1
for epoch in tqdm(range(num_epochs)):
    epoch_loss = 0.0
    sc_decoder = sc_decoder.train().to(device)

    for _id, (cur_batch) in enumerate(train_decoder_dl):

        [latent, trans,] = cur_batch
        latent = latent.to(device)
        trans = trans.to(device)
        sc_dec_optimizer.zero_grad()
        predicted_labels = sc_decoder(latent.float())
        
        this_batch_loss = criter(
            predicted_labels,
            trans.float(),
        )
        
        this_batch_loss.backward()
        epoch_loss += this_batch_loss.item()
        sc_dec_optimizer.step()
# Out:
# scGPT - INFO - match 1569/2000 genes in vocabulary of size 60697.
# Embedding cells: 100%|██████████| 16/16 [00:30<00:00,  1.91s/it]
# 100%|██████████| 16/16 [00:12<00:00,  1.32it/s]
# scGPT - INFO - match 1569/2000 genes in vocabulary of size 60697.
# Embedding cells: 100%|██████████| 16/16 [00:29<00:00,  1.83s/it]
# 100%|██████████| 16/16 [00:10<00:00,  1.51it/s]
# scGPT - INFO - match 1569/2000 genes in vocabulary of size 60697.
# Embedding cells: 100%|██████████| 16/16 [00:28<00:00,  1.78s/it]
# 100%|██████████| 16/16 [00:10<00:00,  1.48it/s]
# scGPT - INFO - match 1569/2000 genes in vocabulary of size 60697.
# Embedding cells: 100%|██████████| 16/16 [00:29<00:00,  1.82s/it]
# 100%|██████████| 16/16 [00:10<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]

# %%
generator = generator.to(device)
discriminator = discriminator.to(device)
hist_decoder = hist_decoder.to(device)
sc_decoder = sc_decoder.to(device)

# gen_optimizer
# disc_optimizer
# hist_dec_optimizer
# sc_dec_optimizer

recon_criter = nn.MSELoss()
num_epochs = 1
for epoch in tqdm(range(num_epochs)):
    generator = generator.train()
    discriminator = discriminator.train()

    for _id, the_batch in enumerate(zip(
        train_sc_dl,
        train_he_dl,
    )):
        (latent_batch, hist_batch) = the_batch

        gen_optimizer.zero_grad()
        disc_optimizer.zero_grad()
        hist_dec_optimizer.zero_grad()
        latent_batch = latent_batch.to(device)
        hist_batch = hist_batch.to(device)

        hist_encoded = generator(hist_batch.float())
        hist_encoded = hist_encoded.detach()

        # put all tensors on the right device 
        source_label, target_label = [1., 0.], [0., 1.]
        encodeds = torch.cat((latent_batch, hist_encoded), axis=0)
        discrim_labels = torch.tensor(
            [source_label] * latent_batch.shape[0]
            + [target_label] * hist_encoded.shape[0]
        ).to(device)

        pred_discrim_labels = discriminator(encodeds.float())
        batch_discrim_loss = F.binary_cross_entropy_with_logits(
            pred_discrim_labels, discrim_labels,
        )

        batch_discrim_loss.backward()
        disc_optimizer.step()     


        #### second part
        for param in discriminator.parameters():
            param.requires_grad = False

        hist_encoded = generator(hist_batch.float())
        hist_discrim_preds = discriminator(hist_encoded)
        he_decoded = hist_decoder(hist_encoded)
            
        discrim_labels = torch.tensor([source_label] * hist_encoded.shape[0]).to(device)
        he_gen_loss = F.binary_cross_entropy_with_logits(
            hist_discrim_preds, discrim_labels, 
        )

        he_recon_loss = recon_criter(
            hist_batch.float(),
            he_decoded,
        )

        beta = .5
        together_loss = beta*he_gen_loss + he_recon_loss
        together_loss.backward()
        # he_gen_loss.backward()
        # he_recon_loss.backward()
        # hist_gen_epoch_loss += he_gen_loss.item()
        # gen_track += he_gen_loss.item() 
        gen_optimizer.step()
        hist_dec_optimizer.step()

        # undo the above
        for param in discriminator.parameters():
            param.requires_grad = True
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]

# %%
tm = TransferModel(generator, sc_decoder).eval()
tm = tm.eval().to(device)
# infer 
inferred_transcripts = []
with torch.no_grad():
    for images in test_he_dl:
        images = images.to(device)        
        outputs = tm(images)
        inferred_transcripts.extend(outputs.cpu().detach().numpy())
        
inferred_adata = sc.AnnData(X=np.array(inferred_transcripts))
inferred_adata.obs = test_he_embeds.obs
